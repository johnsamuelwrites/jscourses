# %%
import os,sys
from PIL import Image
import matplotlib.pyplot as plot
import numpy
from sklearn.linear_model import Perceptron
from sklearn.neural_network import MLPClassifier
from sklearn import svm

imgfile = Image.open("flower.jpg")
print(imgfile.size)

#figure, axes = plot.subplots(nrows=5, ncols=5, figsize=(20,25))

#classifier = Perceptron(max_iter=1000)
#classifier = MLPClassifier(alpha=2, max_iter=1000)
classifier = svm.SVC(gamma=0.001, C=100.)
training_target = ['green', 'green', 'yellow', 'green', 'green',
                   'green', 'yellow', 'yellow', 'yellow', 'green',
                   'green', 'yellow', 'yellow', 'yellow', 'green',
                   'green', 'yellow', 'yellow', 'yellow', 'green',
                   'green', 'yellow', 'yellow', 'yellow', 'green'
                  ]

test_data = []
training_data = []
yaxis= 0
for i in range(0, 640, 128):
    xaxis=0
    for j in range(0,480, 96):
        bbox = (i, j, i+128, j+96)
        axes[xaxis, yaxis].imshow(imgfile.crop(bbox))
        cropimage = imgfile.crop(bbox)
        imagearray = numpy.array(cropimage.getdata(), numpy.uint8)

        if(yaxis < 4):
            training_data.append(imagearray)
        else:
            test_data.append(imagearray)
        xaxis = xaxis + 1

    yaxis = yaxis + 1

training_data = numpy.array(training_data)
training_data = training_data.reshape(training_data.shape[0], -1)
print(training_data.shape)
classifier.fit(training_data, training_target[:20])

test_data = numpy.array(test_data)
test_data = test_data.reshape((test_data.shape[0], -1))
print(classifier.predict(test_data))
plot.show()
# Out:
# (640, 480)
# (20, 36864)
# ['yellow' 'yellow' 'yellow' 'yellow' 'yellow']

# %%
import os,sys
from PIL import Image
import matplotlib.pyplot as plot
import numpy

imgfile = Image.open("flower.jpg")

figure, axes = plot.subplots(nrows=10, ncols=10, figsize=(20,25))

yaxis= 0
for i in range(0, 640, 64):
    xaxis=0
    for j in range(0,480, 48):
        bbox = (i, j, i+64, j+48)
        axes[xaxis, yaxis].imshow(imgfile.crop(bbox))
        xaxis = xaxis + 1

    yaxis = yaxis + 1

plot.show()

# %%
import os,sys
from PIL import Image
import matplotlib.pyplot as plot
import numpy
from sklearn.linear_model import Perceptron
from sklearn.neural_network import MLPClassifier
from sklearn import svm

imgfile = Image.open("flower.jpg")
print(imgfile.size)

#figure, axes = plot.subplots(nrows=5, ncols=5, figsize=(20,25))

#classifier = Perceptron(max_iter=1000)
classifier = MLPClassifier(alpha=2,  tol=0.01)
#classifier = svm.SVC(gamma=0.001, C=100.)
training_target = ['green', 'green', 'green', 'green', 'yellow', 'green', 'green', 'green', 'green', 'green',
                   'green', 'green', 'green', 'green', 'yellow', 'yellow', 'green', 'green', 'green', 'green',
                   'green', 'green', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'green', 'green',
                   'green', 'green', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'green', 'green',
                   'green', 'green', 'green', 'yellow', 'yellow', 'green', 'yellow', 'yellow', 'green', 'green',
                   'green', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'green',
                   'green', 'green', 'green', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'green', 'green',
                   'green', 'green', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'green', 'green',
                   'green', 'green', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'green', 'green',
                   'green', 'green', 'green', 'yellow', 'yellow', 'green', 'yellow', 'green', 'green', 'green'
                  ]

image_data = []
training_data = []
yaxis= 0
for i in range(0, 640, 64):
    xaxis=0
    for j in range(0,480, 48):
        bbox = (i, j, i+64, j+48)
        cropimage = imgfile.crop(bbox)
        imagearray = numpy.array(cropimage.getdata(), numpy.uint8)
        image_data.append(imagearray)
        xaxis = xaxis + 1

    yaxis = yaxis + 1

image_data = numpy.array(image_data)
#image_data = image_data.reshape(image_data.shape[0], -1)
print(image_data.shape)
classifier.fit(image_data[:79], training_target[:79])

print(classifier.predict(image_data[80:]))
# Out:
# (640, 480)

# %%
import os,sys
from PIL import Image
import matplotlib.pyplot as plot
import numpy
from sklearn.linear_model import Perceptron
from sklearn.neural_network import MLPClassifier
from sklearn import svm

imgfile = Image.open("flower.jpg")
print(imgfile.size)

#figure, axes = plot.subplots(nrows=5, ncols=5, figsize=(20,25))

#classifier = Perceptron(max_iter=1000)
classifier = MLPClassifier(alpha=2,  tol=0.01)
#classifier = svm.SVC(gamma=0.001, C=100.)
training_target = ['green', 'green', 'green', 'green', 'yellow', 'green', 'green', 'green', 'green', 'green',
                   'green', 'green', 'green', 'green', 'yellow', 'yellow', 'green', 'green', 'green', 'green',
                   'green', 'green', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'green', 'green',
                   'green', 'green', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'green', 'green',
                   'green', 'green', 'green', 'yellow', 'yellow', 'green', 'yellow', 'yellow', 'green', 'green',
                   'green', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'green',
                   'green', 'green', 'green', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'green', 'green',
                   'green', 'green', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'green', 'green',
                   'green', 'green', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'green', 'green',
                   'green', 'green', 'green', 'yellow', 'yellow', 'green', 'yellow', 'green', 'green', 'green'
                  ]

image_data = []
training_data = []
yaxis= 0
for i in range(0, 640, 64):
    xaxis=0
    for j in range(0,480, 48):
        bbox = (i, j, i+64, j+48)
        cropimage = imgfile.crop(bbox)
        imagearray = numpy.array(cropimage.getdata(), numpy.uint8)
        image_data.append(imagearray)
        if yaxis < 8:
            training_data = []
            training_data.append(imagearray)
            training_data = numpy.array(training_data)
            training_data = training_data.reshape(training_data.shape[0], -1)
            print(training_data)
            #classifier.partial_fit(training_data, [training_target[xaxis + yaxis * 5]], classes=np.unique(training_target))
        xaxis = xaxis + 1
    yaxis = yaxis + 1



print(classifier.predict(image_data[80:]))
# Out:
# (640, 480)
# [[102  94 105 ...  18  13  10]]
# [[55 63 48 ... 25 25 25]]
# [[47 55 42 ... 31 33 28]]
# [[37 37 37 ... 31 30 28]]
# [[44 42 43 ... 39 39 37]]
# [[47 47 47 ... 14 19 12]]
# [[50 50 50 ... 10 10 10]]
# [[53 53 53 ... 17 15 16]]
# [[67 78 72 ... 49 41 54]]
# [[58 60 55 ... 49 45 44]]
# [[49 52 45 ... 29 28 24]]
# [[19 14 10 ...  7  7  5]]
# [[24 26 25 ...  8  9  4]]
# [[31 31 29 ...  5  5  3]]
# [[ 31  31  31 ... 241 198   6]]
# [[ 37  37  37 ... 242 199   7]]
# [[13 21 10 ... 25 27 24]]
# [[ 9  9  9 ... 26 28 27]]
# [[18 16 17 ... 28 30 29]]
# [[46 43 52 ... 49 51 50]]
# [[56 63 55 ... 46 75 57]]
# [[ 28  31  24 ... 244 199   8]]
# [[  8   8   6 ... 243 191  11]]
# [[ 8  9  4 ... 19 24 17]]
# [[  6   5   3 ... 245 191   3]]
# [[242 202   9 ... 252 201  12]]
# [[248 200  14 ... 238 176   5]]
# [[ 25  30  26 ... 251 208  16]]
# [[26 28 27 ... 25 25 25]]
# [[36 40 39 ... 36 36 34]]
# [[55 72 56 ...  8  8  6]]
# [[48 76 54 ... 16 17 12]]
# [[244 201   9 ... 241 172   6]]
# [[243 193  12 ... 251 187   4]]
# [[ 19  26  18 ... 240 160   1]]
# [[244 193   4 ... 231 126   0]]
# [[250 199  10 ... 255 195   9]]
# [[237 173   3 ... 239 172   5]]
# [[249 210  11 ...  39  44  38]]
# [[ 24  24  24 ... 124 131 115]]
# [[ 74  96  75 ... 239 195   8]]
# [[  7   9   8 ... 246 194  10]]
# [[ 17  18  13 ... 243 165   5]]
# [[240 174   2 ... 245 172   5]]
# [[252 187   7 ...  71  35  45]]
# [[243 160   4 ... 214 111   8]]
# [[234 132   4 ... 251 176   5]]
# [[255 196   8 ... 248 193   5]]
# [[238 176   7 ... 251 211  15]]
# [[39 43 42 ... 88 99 91]]
# [[ 57  65  50 ... 237 189   3]]
# [[240 196   9 ... 245 196   8]]
# [[246 197   7 ... 253 196   5]]
# [[243 167   4 ... 239 158   6]]
# [[243 170   5 ... 243 162   8]]
# [[ 69  36  53 ... 235 148   6]]
# [[179  77   0 ... 254 190   5]]
# [[251 179   6 ... 249 199   8]]
# [[246 191   2 ... 241 186   5]]
# [[252 210  12 ...  92 112  85]]
# [[102 133 115 ...  21  24  13]]
# [[241 193   5 ... 109 103  19]]
# [[247 197  12 ... 250 203   9]]
# [[251 193   6 ... 235 178   3]]
# [[242 157   4 ... 249 191   4]]
# [[242 157   4 ... 253 197  16]]
# [[236 152   4 ... 241 181   5]]
# [[252 192   6 ... 246 197  17]]
# [[249 199   8 ...  34  48  33]]
# [[239 189   8 ...  51  54  47]]
# [[57 70 53 ... 44 67 47]]
# [[20 23 14 ... 32 21  3]]
# [[225 173  11 ...  43  65  52]]
# [[251 204  12 ... 238 190   6]]
# [[239 179   5 ...  24  34  25]]
# [[248 194   6 ... 236 176   4]]
# [[252 198  12 ...  53  76  47]]
# [[241 181   5 ...  67  74  30]]
# [[247 196  19 ...  42  63  48]]
# [[37 56 37 ... 37 39 38]]
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-166-587055c21362> in <module>()
#      49
#      50
# ---> 51 print(classifier.predict(image_data[80:]))
#
# ~/.local/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py in predict(self, X)
#     946             The predicted classes.
#     947         """
# --> 948         check_is_fitted(self, "coefs_")
#     949         y_pred = self._predict(X)
#     950
#
# ~/.local/lib/python3.6/site-packages/sklearn/utils/validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#     766
#     767     if not all_or_any([hasattr(estimator, attr) for attr in attributes]):
# --> 768         raise NotFittedError(msg % {'name': type(estimator).__name__})
#     769
#     770
#
# NotFittedError: This MLPClassifier instance is not fitted yet. Call 'fit' with appropriate arguments before using this method.

# %%
from sklearn import datasets, metrics
from sklearn.neural_network import MLPClassifier
import numpy as np
import matplotlib.pyplot as plot

digits = datasets.load_digits()
training_size = int(digits.images.shape[0]/2)

training_images = digits.images[0:training_size]
training_images = training_images.reshape((training_images.shape[0], -1))

training_target = digits.target[0:training_size]

classifier = MLPClassifier(alpha=2, max_iter=1000)
#training
for i in range(training_size):
    training_data = np.array(training_images[i])
    training_data = training_data.reshape(1, -1)
    classifier.partial_fit(training_data, [training_target[i]], classes=np.unique(digits.target))

#prediction
predict_images = digits.images[training_size+1:]
actual_labels = digits.target[training_size+1:]
predicted_labels = classifier.predict(predict_images.reshape((predict_images.shape[0], -1)))

#classification report
print(metrics.classification_report(actual_labels,predicted_labels))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.93      0.97      0.95        88
#           1       0.85      0.81      0.83        91
#           2       0.90      0.97      0.93        86
#           3       0.95      0.82      0.88        91
#           4       0.98      0.92      0.95        92
#           5       0.81      0.92      0.86        91
#           6       0.96      0.99      0.97        91
#           7       0.98      0.92      0.95        89
#           8       0.80      0.80      0.80        87
#           9       0.87      0.87      0.87        92
#
# avg / total       0.90      0.90      0.90       898

# %%
from sklearn import datasets, metrics
from sklearn.linear_model import Perceptron
import numpy as np
import matplotlib.pyplot as plot

digits = datasets.load_digits()
training_size = int(digits.images.shape[0]/2)

training_images = digits.images[0:training_size]
training_images = training_images.reshape((training_images.shape[0], -1))

training_target = digits.target[0:training_size]

classifier = Perceptron(max_iter=1000)
#training
for i in range(training_size):
    training_data = np.array(training_images[i])
    training_data = training_data.reshape(1, -1)
    classifier.partial_fit(training_data, [training_target[i]], classes=np.unique(digits.target))

#prediction
predict_images = digits.images[training_size+1:]
actual_labels = digits.target[training_size+1:]
predicted_labels = classifier.predict(predict_images.reshape((predict_images.shape[0], -1)))

#classification report
print(metrics.classification_report(actual_labels,predicted_labels))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.98      0.92      0.95        88
#           1       1.00      0.44      0.61        91
#           2       0.77      1.00      0.87        86
#           3       0.95      0.77      0.85        91
#           4       0.78      0.90      0.83        92
#           5       0.75      0.92      0.83        91
#           6       0.89      0.99      0.94        91
#           7       1.00      0.88      0.93        89
#           8       0.80      0.80      0.80        87
#           9       0.79      0.89      0.84        92
#
# avg / total       0.87      0.85      0.84       898

# %%
from sklearn import datasets, metrics
from sklearn.neural_network import MLPClassifier
import numpy as np
import matplotlib.pyplot as plot

digits = datasets.load_digits()
training_size = int(digits.images.shape[0]/2)

training_images = digits.images[0:training_size]
training_images = training_images.reshape((training_images.shape[0], -1))

training_target = digits.target[0:training_size]

classifier = MLPClassifier(alpha=2, max_iter=1000)
#training
for i in range(training_size):
    training_data = np.array(training_images[i])
    training_data = training_data.reshape(1, -1)
    classifier.partial_fit(training_data, [training_target[i]], classes=np.unique(digits.target))

#prediction
predict_images = digits.images[training_size+1:]
actual_labels = digits.target[training_size+1:]
predicted_labels = classifier.predict(predict_images.reshape((predict_images.shape[0], -1)))

#classification report
print(metrics.classification_report(actual_labels,predicted_labels))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.98      0.91      0.94        88
#           1       0.65      0.76      0.70        91
#           2       0.98      0.76      0.86        86
#           3       0.59      0.85      0.69        91
#           4       0.87      0.96      0.91        92
#           5       0.73      0.81      0.77        91
#           6       0.84      0.95      0.89        91
#           7       0.91      0.98      0.94        89
#           8       1.00      0.07      0.13        87
#           9       0.69      0.79      0.74        92
#
# avg / total       0.82      0.79      0.76       898

# %%
import tensorflow as tf
from sklearn import datasets
import matplotlib.pyplot as plot
    
digits = datasets.load_digits()
training_size = int(digits.images.shape[0]/2)

training_images = digits.images[0:training_size]
training_images = training_images.reshape((training_images.shape[0], -1))

training_target = digits.target[0:training_size]
print(tf.contrib.layers.real_valued_column("", dimension=8))

classifier = tf.contrib.learn.DNNClassifier(
        feature_columns=[tf.contrib.layers.real_valued_column("", dtype=tf.float64)],
        # 2  hidden layers of 50 nodes each
        hidden_units=[50, 50],
        # 10 classes: 0, 1, 2.....3
         n_classes=10)

#training
classifier.fit(training_images, training_target, steps=100)

#prediction
predict_images = digits.images[training_size+1:]
actual_labels = digits.target[training_size+1:]

predict = classifier.predict(predict_images[16].reshape(1,-1))
print(list(predict))
plot.imshow(predict_images[16], cmap=plot.cm.gray_r)
plot.show()
# Out:
# _RealValuedColumn(column_name='', dimension=8, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpdg8ei802
# INFO:tensorflow:Using config: {'_task_type': None, '_task_id': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f60c5677240>, '_master': '', '_num_ps_replicas': 0, '_num_worker_replicas': 0, '_environment': 'local', '_is_chief': True, '_evaluation_master': '', '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1.0
# }
# , '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_secs': 600, '_log_step_count_steps': 100, '_session_config': None, '_save_checkpoints_steps': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': '/tmp/tmpdg8ei802'}
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into /tmp/tmpdg8ei802/model.ckpt.
# INFO:tensorflow:loss = 9.586682, step = 1
# INFO:tensorflow:Saving checkpoints for 100 into /tmp/tmpdg8ei802/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.02824909.
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# INFO:tensorflow:Restoring parameters from /tmp/tmpdg8ei802/model.ckpt-100
# [0]

# %%
import tensorflow as tf
from sklearn import datasets
import matplotlib.pyplot as plot
    
digits = datasets.load_digits()
training_size = int(digits.images.shape[0]/2)

training_images = digits.images[0:training_size]
training_images = training_images.reshape((training_images.shape[0], -1))

training_target = digits.target[0:training_size]
print(tf.contrib.layers.real_valued_column("", dimension=8))

classifier = tf.contrib.learn.DNNClassifier(
        feature_columns=[tf.contrib.layers.real_valued_column("", dtype=tf.float64)],
        # 2  hidden layers of 50 nodes each
        hidden_units=[50, 50],
        # 10 classes: 0, 1, 2.....9
         n_classes=10)

#training
classifier.fit(training_images, training_target, steps=100)

#prediction
predict_images = digits.images[training_size+1:]
actual_labels = digits.target[training_size+1:]
evaluation = classifier.evaluate(x=predict_images.reshape((predict_images.shape[0], -1)), y=actual_labels)
print(evaluation['accuracy'])
# Out:
# _RealValuedColumn(column_name='', dimension=8, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmp_oon0k6i
# INFO:tensorflow:Using config: {'_task_type': None, '_task_id': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f60c69cc5f8>, '_master': '', '_num_ps_replicas': 0, '_num_worker_replicas': 0, '_environment': 'local', '_is_chief': True, '_evaluation_master': '', '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1.0
# }
# , '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_secs': 600, '_log_step_count_steps': 100, '_session_config': None, '_save_checkpoints_steps': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': '/tmp/tmp_oon0k6i'}
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into /tmp/tmp_oon0k6i/model.ckpt.
# INFO:tensorflow:loss = 5.657029, step = 1
# INFO:tensorflow:Saving checkpoints for 100 into /tmp/tmp_oon0k6i/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.018497193.
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# INFO:tensorflow:Starting evaluation at 2018-03-01-10:48:59
# INFO:tensorflow:Restoring parameters from /tmp/tmp_oon0k6i/model.ckpt-100
# INFO:tensorflow:Finished evaluation at 2018-03-01-10:48:59
# INFO:tensorflow:Saving dict for global step 100: accuracy = 0.9175947, global_step = 100, loss = 0.30887508
# 0.9175947
